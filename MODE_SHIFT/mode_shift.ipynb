# %%
# %pip install folium pandas requests openpyxl
# Out:
# ...
#
# ...

# %%
googoe_maps_api_key= "AIzaSyBv9J9W-g_N2i2jixXo7lVHBf-D_ph7bds"

# %%
import folium
import pandas as pd

# Define the original data based on the new provided information
data = {
    'Origin Country': ['SEMMA'] * 16,
    'Destination Code': [
        'US', 'USATL', 'USCMH', 'USDFW', 'USEWR', 'USHOU', 'USJFK', 'USLAX', 
        'USMIA', 'USMKC', 'USMSP', 'USORD', 'USPHX', 'USSFO', 'USSLC', 'USWJN'
    ],
    'Volume (m3)': [
        4.26, 34.59, 12.09, 24.99, 1.37, 261.94, 35.53, 19.18, 0.94, 0.91, 
        166.36, 1532.90, 22.91, 0.05, 8.78, 13.99
    ]
}

# Create the DataFrame
df = pd.DataFrame(data)

# Create a dictionary to map destination codes to coordinates (latitude, longitude)
location_coords = {
    'US': (37.0902, -95.7129),        # General USA location
    'USATL': (33.7490, -84.3880),     # Atlanta, GA
    'USCMH': (39.9612, -82.9988),     # Columbus, OH
    'USDFW': (32.7767, -96.7970),     # Dallas-Fort Worth, TX
    'USEWR': (40.6895, -74.1745),     # Newark, NJ
    'USHOU': (29.7604, -95.3698),     # Houston, TX
    'USJFK': (40.6413, -73.7781),     # New York JFK
    'USLAX': (34.0522, -118.2437),    # Los Angeles, CA
    'USMIA': (25.7617, -80.1918),     # Miami, FL
    'USMKC': (39.0997, -94.5786),     # Kansas City, MO
    'USMSP': (44.9778, -93.2650),     # Minneapolis, MN
    'USORD': (41.9742, -87.9073),     # Chicago O'Hare International Airport
    'USPHX': (33.4484, -112.0740),    # Phoenix, AZ
    'USSFO': (37.7749, -122.4194),    # San Francisco, CA
    'USSLC': (40.7608, -111.8910),    # Salt Lake City, UT
    'USWJN': (47.6062, -122.3321)     # Seattle, WA (approximation for Washington State)
}


# Display the DataFrame
# Print DataFrame and location coordinates
print(df)
print(location_coords)

# Calculate the center of gravity
total_volume = df['Volume (m3)'].sum()
weighted_lat = 0
weighted_lon = 0

for index, row in df.iterrows():
    dest_code = row['Destination Code']
    volume = row['Volume (m3)']
    if dest_code in location_coords:
        lat, lon = location_coords[dest_code]
        weighted_lat += lat * volume
        weighted_lon += lon * volume

center_of_gravity_lat = weighted_lat / total_volume
center_of_gravity_lon = weighted_lon / total_volume

# Create a map centered on the United States
map_usa = folium.Map(location=[39.8283, -98.5795], zoom_start=4)

# Iterate over the DataFrame and add markers for each location
for index, row in df.iterrows():
    dest_code = row['Destination Code']
    volume = row['Volume (m3)']
    if dest_code in location_coords:
        lat, lon = location_coords[dest_code]
        radius = volume *0.3  # Adjust the scaling factor as needed
        folium.CircleMarker(location=[lat, lon], radius=radius, popup=f"{dest_code}: {volume} m3", fill=True).add_to(map_usa)

# Add a marker for the center of gravity
folium.Marker(location=[center_of_gravity_lat, center_of_gravity_lon], popup="Center of Gravity", icon=folium.Icon(color='red')).add_to(map_usa)

# Save the map as an HTML file
map_usa.save('Tetra Pakusa_map_with_volume_and_cog.html')
# Out:
#    Origin Country Destination Code  Volume (m3)
# 0           SEMMA               US         4.26
# 1           SEMMA            USATL        34.59
# 2           SEMMA            USCMH        12.09
# 3           SEMMA            USDFW        24.99
# 4           SEMMA            USEWR         1.37
# 5           SEMMA            USHOU       261.94
# 6           SEMMA            USJFK        35.53
# 7           SEMMA            USLAX        19.18
# 8           SEMMA            USMIA         0.94
# 9           SEMMA            USMKC         0.91
# 10          SEMMA            USMSP       166.36
# 11          SEMMA            USORD      1532.90
# 12          SEMMA            USPHX        22.91
# 13          SEMMA            USSFO         0.05
# 14          SEMMA            USSLC         8.78
# 15          SEMMA            USWJN        13.99
# ...

# %%
import folium
import pandas as pd

# Create a DataFrame with the location data and volume

# Create the data dictionary
# Create the data dictionary
data = {
    'Origin Country': ['SEMMA'] * 16,
    'Destination Code': [
        'US', 'USATL', 'USCMH', 'USDFW', 'USEWR', 'USHOU', 'USJFK', 'USLAX', 
        'USMIA', 'USMKC', 'USMSP', 'USORD', 'USPHX', 'USSFO', 'USSLC', 'USWJN'
    ],
    'Volume (m3)': [
        4.26, 34.59, 12.09, 24.99, 1.37, 261.94, 35.53, 19.18, 0.94, 0.91, 
        166.36, 1532.90, 22.91, 0.05, 8.78, 13.99
    ]
}

# Create the DataFrame
df = pd.DataFrame(data)

# Create a dictionary to map destination codes to coordinates (latitude, longitude)
location_coords = {
    'US': (37.0902, -95.7129),        # General USA location
    'USATL': (33.7490, -84.3880),     # Atlanta, GA
    'USCMH': (39.9612, -82.9988),     # Columbus, OH
    'USDFW': (32.7767, -96.7970),     # Dallas-Fort Worth, TX
    'USEWR': (40.6895, -74.1745),     # Newark, NJ
    'USHOU': (29.7604, -95.3698),     # Houston, TX
    'USJFK': (40.6413, -73.7781),     # New York JFK
    'USLAX': (34.0522, -118.2437),    # Los Angeles, CA
    'USMIA': (25.7617, -80.1918),     # Miami, FL
    'USMKC': (39.0997, -94.5786),     # Kansas City, MO
    'USMSP': (44.9778, -93.2650),     # Minneapolis, MN
    'USORD': (41.9742, -87.9073),     # Chicago O'Hare International Airport
    'USPHX': (33.4484, -112.0740),    # Phoenix, AZ
    'USSFO': (37.7749, -122.4194),    # San Francisco, CA
    'USSLC': (40.7608, -111.8910),    # Salt Lake City, UT
    'USWJN': (47.6062, -122.3321)     # Seattle, WA (approximation for Washington State)
}


# Set the coordinates for a point in the UK (e.g., London)
uk_lat, uk_lon = 55.6050, 13.0038 
# Create a map centered on the United States
map_usa = folium.Map(location=[39.8283, -98.5795], zoom_start=4)

# Iterate over the DataFrame and add markers and lines for each location
for index, row in df.iterrows():
    dest_code = row['Destination Code']
    volume = row['Volume (m3)']
    if dest_code in location_coords:
        lat, lon = location_coords[dest_code]
        radius =  2  # Adjust the scaling factor as needed
        folium.CircleMarker(location=[lat, lon], radius=radius, popup=f"{dest_code}: {volume} m3", fill=True).add_to(map_usa)
        
        # Draw a line from the UK to the current location
        folium.PolyLine(locations=[[uk_lat, uk_lon], [lat, lon]], color='blue', weight=1).add_to(map_usa)

# Add a marker for the UK point
folium.Marker(location=[uk_lat, uk_lon], popup="UK", icon=folium.Icon(color='blue')).add_to(map_usa)

# Save the map as an HTML file
map_usa.save('teeeeusa_map_with_lines_from_dk.html')

# %%
import folium
import pandas as pd

# Create a DataFrame with the location data and volume
# Create the data dictionary
data = {
    'Origin Country': [
        'SEHSQ', 'SEHSQ', 'SEHSQ', 'SEHSQ', 'SEHSQ', 'SEHSQ', 'SEHSQ', 'SEHSQ', 'SEHSQ', 'SEHSQ'
    ],
    'Destination Code': [
        'US', 'USATL', 'USCLT', 'USDFW', 'USLXA', 'USOGB', 'USOLB', 'USORD', 'USUBV', 'USZNV'
    ],
    'Volume (m3)': [
        294.56, 2.68, 15.85, 41.83, 439.10, 172.20, 15.07, 1.56, 156.53, 209.18
    ]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Create a dictionary to map destination codes to coordinates (latitude, longitude)
location_coords = {
    'US': (37.0902, -95.7129),        # General USA location
    'USATL': (33.7490, -84.3880),     # Atlanta, GA
    'USCLT': (35.2271, -80.8431),     # Charlotte, NC
    'USDFW': (32.7767, -96.7970),     # Dallas-Fort Worth, TX
    'USLXA': (36.1699, -115.1398),    # Las Vegas, NV
    'USOGB': (44.5192, -88.0198),     # Green Bay, WI
    'USOLB': (33.7701, -118.1937),    # Long Beach, CA
    'USORD': (41.9742, -87.9073),     # Chicago O'Hare International Airport
    'USUBV': (40.7128, -74.0060),     # New York City, NY (Example)
    'USZNV': (39.7392, -104.9903)     # Denver, CO
}

# Set the coordinates for a point in the UK (e.g., London) and Chicago
gothenburg_lat, gothenburg_lon = (57.7089, 11.9746)  # Gothenburg coordinates
chicago_lat, chicago_lon = location_coords['USORD']

# Create a map centered on the United States
map_usa = folium.Map(location=[39.8283, -98.5795], zoom_start=4)

# Draw a line from the UK to Chicago
folium.PolyLine(locations=[[gothenburg_lat, gothenburg_lon], [chicago_lat, chicago_lon]], color='blue', weight=2).add_to(map_usa)

# Iterate over the DataFrame and add markers and lines for each location
for index, row in df.iterrows():
    dest_code = row['Destination Code']
    volume = row['Volume (m3)']
    if dest_code in location_coords:
        lat, lon = location_coords[dest_code]
        radius = volume * 2  # Adjust the scaling factor as needed
        folium.CircleMarker(location=[lat, lon], radius=radius, popup=f"{dest_code}: {volume} m3", fill=True).add_to(map_usa)
        
        # Draw a line from Chicago to the current location
        folium.PolyLine(locations=[[chicago_lat, chicago_lon], [lat, lon]], color='green', weight=1).add_to(map_usa)

# Add a marker for the UK point
folium.Marker(location=[gothenburg_lat, gothenburg_lon], popup="SE", icon=folium.Icon(color='blue')).add_to(map_usa)

# Add a marker for Chicago
folium.Marker(location=[chicago_lat, chicago_lon], popup="Chicago", icon=folium.Icon(color='blue')).add_to(map_usa)

# Save the map as an HTML file
map_usa.save('HUSQVARNAusa_map_with_lines_from_uk_to_chicago.html')

# %%
import folium
import pandas as pd

# Create the data dictionary

# Original data
data = {
    'Origin Country': ['SEMMA'] * 16,
    'Destination Code': [
        'US', 'USATL', 'USCMH', 'USDFW', 'USEWR', 'USHOU', 'USJFK', 'USLAX', 
        'USMIA', 'USMKC', 'USMSP', 'USORD', 'USPHX', 'USSFO', 'USSLC', 'USWJN'
    ],
    'Volume (m3)': [
        4.26, 34.59, 12.09, 24.99, 1.37, 261.94, 35.53, 19.18, 0.94, 0.91, 
        166.36, 1532.90, 22.91, 0.05, 8.78, 13.99
    ]
}

# Create the DataFrame
df = pd.DataFrame(data)

# Create a dictionary to map destination codes to coordinates (latitude, longitude)
location_coords = {
    'US': (37.0902, -95.7129),        # General USA location
    'USATL': (33.7490, -84.3880),     # Atlanta, GA
    'USCMH': (39.9612, -82.9988),     # Columbus, OH
    'USDFW': (32.7767, -96.7970),     # Dallas-Fort Worth, TX
    'USEWR': (40.6895, -74.1745),     # Newark, NJ
    'USHOU': (29.7604, -95.3698),     # Houston, TX
    'USJFK': (40.6413, -73.7781),     # New York JFK
    'USLAX': (34.0522, -118.2437),    # Los Angeles, CA
    'USMIA': (25.7617, -80.1918),     # Miami, FL
    'USMKC': (39.0997, -94.5786),     # Kansas City, MO
    'USMSP': (44.9778, -93.2650),     # Minneapolis, MN
    'USORD': (41.9742, -87.9073),     # Chicago O'Hare International Airport
    'USPHX': (33.4484, -112.0740),    # Phoenix, AZ
    'USSFO': (37.7749, -122.4194),    # San Francisco, CA
    'USSLC': (40.7608, -111.8910),    # Salt Lake City, UT
    'USWJN': (47.6062, -122.3321)     # Seattle, WA (approximation for Washington State)
}

# Set the coordinates for Gothenburg and Chicago
gothenburg_lat, gothenburg_lon = (57.7089, 11.9746)  # Gothenburg coordinates
chicago_lat, chicago_lon = location_coords['USORD']

# Define the coordinates for the waterway path from Gothenburg to Chicago
waterway_path = [
    (gothenburg_lat, gothenburg_lon),  # Gothenburg
    (50.0000, 0.0000),  # Pass through the British Channel
    (50.0000, -5.0000),  # Near the British Channel exit
    (47.5580, -59.5817),  # Gulf of St. Lawrence
    (49.2827, -68.2070),  # Saguenay River
    (48.4283, -71.0589),  # Quebec City
    (45.5017, -73.5673),  # Montreal
    (45.2540, -74.1327),  # Beauharnois Canal
    (45.0084, -74.7298),  # Cornwall (St. Lawrence River)
    (44.2253, -76.4951),  # Kingston (Lake Ontario)
    (43.6532, -79.3832),  # Toronto (Lake Ontario)
    (43.2501, -79.8496),  # Hamilton (Lake Ontario)
    (42.8864, -78.8781),  # Buffalo (Lake Erie)
    (41.4993, -81.6944),  # Cleveland (Lake Erie)
    (42.3314, -83.0458),  # Detroit (Detroit River)
    (42.3222, -82.9922),  # Lake St. Clair
    (43.0004, -82.4192),  # Port Huron (St. Clair River)
    (44.3148, -83.1076),  # Alpena (Lake Huron)
    (45.7733, -84.7344),  # Mackinac Bridge (Straits of Mackinac)
    (45.8516, -84.6158),  # St. Ignace (Lake Michigan)
    (43.6156, -86.4898),  # Muskegon (Lake Michigan)
    (41.9742, -87.9073)   # Chicago
]

# Create a map centered on the United States
map_usa = folium.Map(location=[39.8283, -98.5795], zoom_start=4)

# Draw a line from Gothenburg to Chicago following the waterway path
folium.PolyLine(locations=waterway_path, color='blue', weight=2).add_to(map_usa)

# Iterate over the DataFrame and add markers and lines for each location
for index, row in df.iterrows():
    dest_code = row['Destination Code']
    volume = row['Volume (m3)']
    if dest_code in location_coords:
        lat, lon = location_coords[dest_code]
        radius = volume * 0.04  # Adjust the scaling factor as needed
        folium.CircleMarker(location=[lat, lon], radius=radius, popup=f"{dest_code}: {volume} m3", fill=True, fill_color='#0000FF', color='#0000FF').add_to(map_usa)
        
        # Draw a line from Chicago to the current location
        folium.PolyLine(locations=[[chicago_lat, chicago_lon], [lat, lon]], color='green', weight=1).add_to(map_usa)

# Add a marker for Gothenburg
folium.Marker(location=[gothenburg_lat, gothenburg_lon], popup="Gothenburg", icon=folium.Icon(color='blue')).add_to(map_usa)

# Add a marker for Chicago
folium.Marker(location=[chicago_lat, chicago_lon], popup="Chicago", icon=folium.Icon(color='blue')).add_to(map_usa)

# Save the map as an HTML file
map_usa.save('Tetrausa_map_with_waterway_path.html')
